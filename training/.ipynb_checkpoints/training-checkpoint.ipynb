# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = tf.keras.utils.image_dataset_from_directory(
    'data',
    shuffle = True,
    batch_size = 30,
)
# Out:
# Found 4188 files belonging to 4 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Blight', 'Common_Rust', 'Gray_Leaf_Spot', 'Healthy']

# %%
len(dataset)
# Out:
# 140

# %%
for image_batch,label_batch in dataset.take(1):
    print(image_batch.shape)
    print(label_batch.numpy())
# Out:
# (30, 256, 256, 3)
# [3 3 3 1 0 1 3 0 1 1 0 1 3 3 2 3 3 0 1 3 3 2 0 3 0 1 0 0 0 1]

# %%
plt.figure(figsize=(10,10))
for image_batch,label_batch in dataset.take(1):
    for i in range (12):
        plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_names[label_batch[i]])
        plt.axis('off')

# %%
#training ==> 80% of data
#validation ==> 10% of data
#test ==> 10% of data

# %%
def split_dataset(ds,train_split,val_split,test_split,shuffle=True,shuffle_size = 10000):

    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size,seed=20)

    train_size = int(ds_size*train_split)
    val_size = int(ds_size*val_split)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds,val_ds,test_ds

# %%
train_ds, val_ds, test_ds = split_dataset(dataset,0.8,0.1,0.1)

# %%
lengths = [len(train_ds),len(val_ds),len(test_ds)]
print(f'Lengths = Train:{lengths[0]}, Validation:{lengths[1]}, Test:{lengths[2]}')
# Out:
# Lengths = Train:112, Validation:14, Test:14

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE) 
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(256, 256),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip('horizontal_and_vertical'),
    layers.experimental.preprocessing.RandomRotation(0.2)
])

# %%
model = tf.keras.models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(filters = 30, kernel_size = (3,3), activation='relu',input_shape=(30, 256, 256, 3)),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(60, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(60, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(60, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(60, activation='relu'),
    layers.Dense(4, activation='softmax')    
])

model.build(input_shape = (30, 256, 256, 3))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (30, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (30, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (30, 254, 254, 30)        840
#
#  max_pooling2d (MaxPooling2D  (30, 127, 127, 30)       0
#  )
#
#  conv2d_1 (Conv2D)           (30, 125, 125, 60)        16260
#
#  max_pooling2d_1 (MaxPooling  (30, 62, 62, 60)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (30, 60, 60, 60)          32460
#
#  max_pooling2d_2 (MaxPooling  (30, 30, 30, 60)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (30, 28, 28, 60)          32460
#
#  max_pooling2d_3 (MaxPooling  (30, 14, 14, 60)         0
#  2D)
#
#  flatten (Flatten)           (30, 11760)               0
#
#  dense (Dense)               (30, 60)                  705660
#
#  dense_1 (Dense)             (30, 4)                   244
#
# =================================================================
# Total params: 787,924
# Trainable params: 787,924
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = 'SparseCategoricalCrossentropy',
    metrics = ['Accuracy']
)

# %%
history = model.fit(
    train_ds,
    epochs = 100,
    verbose = 1,
    validation_data = val_ds
)
# Out:
# Epoch 1/100
# 112/112 [==============================] - 105s 695ms/step - loss: 0.6527 - Accuracy: 0.7237 - val_loss: 0.5207 - val_Accuracy: 0.8113
# Epoch 2/100
# 112/112 [==============================] - 56s 495ms/step - loss: 0.4257 - Accuracy: 0.8154 - val_loss: 0.4825 - val_Accuracy: 0.8431
# Epoch 3/100
# 112/112 [==============================] - 53s 472ms/step - loss: 0.4041 - Accuracy: 0.8292 - val_loss: 0.4719 - val_Accuracy: 0.8309
# Epoch 4/100
# 112/112 [==============================] - 53s 472ms/step - loss: 0.4148 - Accuracy: 0.8289 - val_loss: 0.4057 - val_Accuracy: 0.8578
# Epoch 5/100
# 112/112 [==============================] - 53s 473ms/step - loss: 0.3474 - Accuracy: 0.8429 - val_loss: 0.4752 - val_Accuracy: 0.8235
# Epoch 6/100
# 112/112 [==============================] - 53s 473ms/step - loss: 0.3299 - Accuracy: 0.8578 - val_loss: 0.3633 - val_Accuracy: 0.8603
# Epoch 7/100
# 112/112 [==============================] - 53s 473ms/step - loss: 0.3303 - Accuracy: 0.8545 - val_loss: 0.3564 - val_Accuracy: 0.8554
# Epoch 8/100
# 112/112 [==============================] - 53s 472ms/step - loss: 0.3245 - Accuracy: 0.8689 - val_loss: 0.3987 - val_Accuracy: 0.8750
# Epoch 9/100
# 112/112 [==============================] - 53s 472ms/step - loss: 0.2845 - Accuracy: 0.8805 - val_loss: 0.3296 - val_Accuracy: 0.8922
# Epoch 10/100
# 112/112 [==============================] - 53s 471ms/step - loss: 0.2941 - Accuracy: 0.8793 - val_loss: 0.3242 - val_Accuracy: 0.8775
# Epoch 11/100
# 112/112 [==============================] - 53s 471ms/step - loss: 0.2663 - Accuracy: 0.8868 - val_loss: 0.3876 - val_Accuracy: 0.8676
# Epoch 12/100
# 112/112 [==============================] - 53s 471ms/step - loss: 0.2670 - Accuracy: 0.8901 - val_loss: 0.2604 - val_Accuracy: 0.9044
# Epoch 13/100
# 112/112 [==============================] - 53s 471ms/step - loss: 0.2471 - Accuracy: 0.8987 - val_loss: 0.3695 - val_Accuracy: 0.8382
# Epoch 14/100
# 112/112 [==============================] - 53s 471ms/step - loss: 0.2426 - Accuracy: 0.9008 - val_loss: 0.2441 - val_Accuracy: 0.8971
# Epoch 15/100
# 112/112 [==============================] - 53s 470ms/step - loss: 0.1049 - Accuracy: 0.9597 - val_loss: 0.1214 - val_Accuracy: 0.9657
# Epoch 95/100
# 112/112 [==============================] - 53s 470ms/step - loss: 0.0834 - Accuracy: 0.9662 - val_loss: 0.0683 - val_Accuracy: 0.9804
# Epoch 96/100
# 112/112 [==============================] - 53s 469ms/step - loss: 0.0779 - Accuracy: 0.9689 - val_loss: 0.0786 - val_Accuracy: 0.9730
# Epoch 97/100
# 112/112 [==============================] - 53s 469ms/step - loss: 0.0695 - Accuracy: 0.9746 - val_loss: 0.0760 - val_Accuracy: 0.9706
# Epoch 98/100
# 112/112 [==============================] - 53s 470ms/step - loss: 0.0831 - Accuracy: 0.9654 - val_loss: 0.1049 - val_Accuracy: 0.9632
# Epoch 99/100
# 112/112 [==============================] - 53s 469ms/step - loss: 0.0812 - Accuracy: 0.9695 - val_loss: 0.1514 - val_Accuracy: 0.9706
# Epoch 100/100
# 112/112 [==============================] - 53s 469ms/step - loss: 0.0786 - Accuracy: 0.9680 - val_loss: 0.1188 - val_Accuracy: 0.9632

# %%
model.evaluate(test_ds)
# Out:
# 14/14 [==============================] - 27s 160ms/step - loss: 0.1048 - Accuracy: 0.9619
# [0.10481996834278107, 0.961904764175415]

# %%
history

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'Accuracy', 'val_loss', 'val_Accuracy'])

# %%
accuracy, va_accuracy, loss, va_loss = history.history['Accuracy'], history.history['val_Accuracy'], history.history['loss'], history.history['val_loss']

# %%
plt.figure(figsize=(8,8))
plt.subplot(1, 2, 1)
plt.plot(accuracy,label='Training Accuacy')
plt.plot(va_accuracy,label='Validation Accuacy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss,label='Training Loss')
plt.plot(va_loss,label='Validation Loss')
plt.legend(loc='lower right')
plt.title('Training and Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.images.image_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0) #Create a batch
    
    predictions = model.predict(img_array)
    
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100*(np.max(predictions[0])),2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15,15))
for images, labels in test_ds.take(1):
    for i in range(9):
        plt.subplot(3, 3, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]
        
        plt.title(f'Actual:{actual_class}\nPredicted:{predicted_class}')
        plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[102], line 7
#       4 plt.subplot(3, 3, i+1)
#       5 plt.imshow(images[i].numpy().astype('uint8'))
# ----> 7 predicted_class, confidence = predict(model, images[i].numpy())
#       8 actual_class = class_names[labels[i]]
#      10 plt.title(f'Actual:{actual_class}\nPredicted:{predicted_class}')
#
# Cell In[101], line 2, in predict(model, img)
#       1 def predict(model, img):
# ----> 2     img_array = tf.keras.preprocessing.image.image_to_array(images[i].numpy())
#       3     img_array = tf.expand_dims(img_array, 0) #Create a batch
#       5     predictions = model.predict(img_array)
#
# AttributeError: module 'keras.api._v2.keras.preprocessing.image' has no attribute 'image_to_array'
